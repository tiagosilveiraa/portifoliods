# %% [markdown]
# <a href="https://colab.research.google.com/github/tiagosilveiraa/portifoliods/blob/main/Classifica%C3%A7%C3%A3o%20da%20perman%C3%AAncia%20de%20moradores%20de%20rua%20em%20abrigos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PUC Minas**
#
# # **Pós Graduação em Ciência de Dados e Big Data**
#
#
# **Trabalho de conclusão de curso**
#
#
# **Título:** MÉTODOS DE PREDIÇÃO APLICADOS A RETENÇÃO DE MORADORES DE RUA EM ABRIGOS.
#
#
# **Aluno:** Tiago da Silveira Mariano

# %% [markdown]
# # Importação de Bibliotecas

# %%
# !pip install unidecode --quiet
# !pip install gmaps --quiet
# !pip install bs4 --quiet
# Out:
#      |████████████████████████████████| 235 kB 4.2 MB/s
#      |████████████████████████████████| 1.1 MB 4.2 MB/s
#      |████████████████████████████████| 1.6 MB 45.0 MB/s
#   Building wheel for gmaps (setup.py) ... done

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import requests 
import unicodedata
import plotly.express as px
import gmaps
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from unidecode import unidecode
from scipy import stats
from google.colab import output
from matplotlib import rcParams
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import VarianceThreshold
from google.colab import data_table

# %%
# Aumenta o tamanho dos gráficos
rcParams['figure.figsize'] = 12.7,9.27
rcParams['axes.titlesize'] = 22
rcParams['axes.labelsize'] = 16
#Numero de linhas do Pandas ao exibir dados
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
#Necessário para a exibição do heatmap
output.enable_custom_widget_manager()
#Setando paletta de cores do SNS
sns.set_palette("Paired")
data_table.enable_dataframe_formatter()
np.random.seed(777)

# %%
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %% [markdown]
# # 1 - Coleta de dados
# Inicialmente vamos carregar o dataset do Censo com os dados da pesquisa. Optei por hospedar o dataset no github para garantir a disponibilidade do mesmo, além disto minimizei os cabeçalhos para uma melhor manipulação dos dados.
#
# O Link original do dataset é: https://pcrj.maps.arcgis.com/sharing/rest/content/items/97d55e185d114698ac5472f6f1c43758/data

# %%
df_censo = pd.read_csv('https://github.com/tiagosilveiraa/tccbigdata/raw/main/Dados_Censo_PopRua_2020.csv', sep=';', low_memory=False)                           
df_censo = df_censo.rename(str.lower, axis='columns')

# %% [markdown]
# ##1.1 - Enriquecimento dos dados
#
# Para enriquecer os nossos dados vamos montar outro dataset com o IDS - Indíce de Desenvolvimento Social de cada bairro.

# %%
page = requests.get('https://pt.wikipedia.org/wiki/Lista_de_bairros_do_Rio_de_Janeiro_por_%C3%8Dndice_de_Desenvolvimento_Social')

# %%
soup = BeautifulSoup(page.content, 'html.parser', from_encoding="utf-8")
tabela = soup.find('tbody')
linhas = tabela.findAll('tr')

# %%
df_ids = pd.DataFrame()
for l in linhas:
  colunas = l.findAll('td')
  if(colunas != []):
   df_ids = df_ids.append({
      'bairro': colunas[1].get_text().replace('\n',''),     
      'zona': colunas[3].get_text().replace('\n','').replace('Zona', '').strip(),
      'ids': float(colunas[4].get_text().replace('\n','').replace(',','.')),
    }, ignore_index = True)

# %% [markdown]
# # 2 - Tratamento de Dados
# Nesta etapa iremos fazer a limpeza e o tratamento de dados, além da junção entre os dois datasets.
#
# Para este estudo só são necessários os registros onde a entrevista foi possível, o indivíduo respondeu ao questionário, está em situação de rua e já dormiu em abrigos da prefeitura, sendo assim, iremos fazer a limpeza dos demais.

# %%
df_censo = df_censo.loc[(~df_censo['dormiu_abrigo_prefeitura'].isin(['Não', 'NS/NR', 'Não se aplica']))]
df_censo = df_censo.reset_index(drop=True)

# %% [markdown]
# ##2.1 - Padronizando os caracteres entre os datasets

# %% [markdown]
# Removendo acentos e colocando letras em maiúsculo.

# %%
df_censo = df_censo.applymap(lambda s: unidecode(s.upper()) if type(s) == str else s)
df_ids = df_ids.applymap(lambda s: unidecode(s.upper()) if type(s) == str else s)

# %% [markdown]
# Alterando o nome da feature para melhor legibilidade

# %%
df_censo.rename({'dormiu_abrigo_prefeitura': 'permanece_abrigo_prefeitura'}, axis = 1, inplace= True)
df_censo.loc[df_censo['permanece_abrigo_prefeitura'] == 'SIM, MAS DEIXEI DE DORMIR', 'permanece_abrigo_prefeitura'] = 'NAO PERMANECE'
df_censo.loc[df_censo['permanece_abrigo_prefeitura'] == 'SIM, E CONTINUO DORMINDO SEMPRE OU DE VEZ EM QUANDO', 'permanece_abrigo_prefeitura'] = 'PERMANECE'

# %% [markdown]
# ## 2.2 - Verificando se existem bairros no censo que não estão no dataframe de IDS

# %%
bairros_censo = pd.DataFrame(np.unique(df_censo['bairro']), columns=['bairro'])
diff = bairros_censo.merge(df_ids['bairro'], on='bairro', how="outer", indicator=True).drop_duplicates(keep=False)
diff.loc[diff['_merge']=='left_only']
# Out:
#                  bairro     _merge
# 48                 LAPA  left_only
# 52  LINS DE VASCONCELOS  left_only
# 64      PARADA DE LUCAS  left_only

# %% [markdown]
# ### 2.2.1 - Corrigindo diferenças de escrita do dataframe de IDS

# %%
df_ids.loc[df_ids['bairro'] == 'LINS DE VASCONCELLOS', 'bairro'] = 'LINS DE VASCONCELOS'
df_ids.loc[df_ids['bairro'] == 'PARADA DE  LUCAS', 'bairro'] = 'PARADA DE LUCAS'

# %% [markdown]
# ### 2.2.2 - Incluindo bairros ausentes no dataset IDS.
# Como não temos o IDS, para estes bairros irei preencher com a média das suas zonas.

# %%
df_ids = df_ids.append({
        'zona':'CENTRAL',
        'bairro':'LAPA',
        'ids': df_ids.loc[df_ids['zona'] == 'CENTRAL', 'ids'].mean()
    }, ignore_index=True)

# %% [markdown]
# Checando se ainda existe algum bairro presente na lista do censo e que não consta na relação de bairros com zonas classificadas.

# %%
bairros_censo = pd.DataFrame(np.unique(df_censo['bairro']), columns=['bairro'])
diff = bairros_censo.merge(df_ids['bairro'], on='bairro', how="outer", indicator=True).drop_duplicates(keep=False)
diff.loc[diff['_merge']=='left_only']
# Out:
# Empty DataFrame
# Columns: [bairro, _merge]
# Index: []

# %% [markdown]
# ## 2.2 - Unindo os dados dos dois datasets

# %%
df_censo = df_censo.merge(df_ids, on='bairro')

# %% [markdown]
# ## 2.3 - Tratamento de registros inválidos

# %%
df_clean = df_censo
del df_censo

# %% [markdown]
# ### 2.3.1 - Buscando por colunas com registros inválidos (NaN)

# %%
df_clean.columns[df_clean.isna().any()].tolist()
# Out:
# ['unidade_de_acolhimento_us', 'data', 'onde_estava_antes_acolhimento']

# %%
df_clean.loc[df_clean['data'].isna(), ['data']] = df_clean['data'].mode().values[0]

# %% [markdown]
# Nota-se que os campos 'onde_estava_antes_acolhimento', 'data' e 'unidade_de_acolhimento_us' não estão preenchidos pois os indivíduos ainda estão em situação de rua, por isso irei dropar as colunas.

# %%
df_clean = df_clean.drop(columns=['unidade_de_acolhimento_us', 'onde_estava_antes_acolhimento'])

# %% [markdown]
# ###2.3.2 - Tratando outliers e valores inválidos.

# %% [markdown]
# Com o código a função abaixo e visualizando o boxplot percebemos que existem outliers nas informações das idades dos indivíduos, vamos investigar.

# %%
df_clean.describe()
# Out:
#                 id  codigo_da_rp  codigo_da_ra        idade          ids
# count  1609.000000   1609.000000   1609.000000  1609.000000  1609.000000
# mean   1863.016781      2.337166      8.245494    42.528900     0.633580
# std    1497.258791      1.261957      7.340342    54.839413     0.079309
# min       3.000000      1.100000      1.000000    12.000000     0.433000
# 25%     773.000000      1.100000      2.000000    30.000000     0.586000
# 50%    1397.000000      2.100000      5.000000    38.000000     0.629000
# 75%    2154.000000      3.300000     13.000000    48.000000     0.679000
# max    6980.000000      5.400000     34.000000   999.000000     0.854000

# %%
sns.boxplot(x=df_clean['idade'])

# %%
df_clean.loc[(np.abs(stats.zscore(df_clean['idade'])) >= 3)]
# Out:
# Warning: Total number of columns (131) exceeds max_columns (20). Falling back to pandas display.
#         id rua_acolhimento local_da_coleta_de_dados      metodo  \
# 911   4341             RUA             CENAS DE USO  ENTREVISTA
# 1489  4685             RUA             CENAS DE USO  ENTREVISTA
# 1493  4695             RUA             CENAS DE USO  ENTREVISTA
# 1531  4602             RUA             CENAS DE USO  ENTREVISTA
# 1572  6972             RUA         HOSPITAIS E CAPS  ENTREVISTA
#
#               turno        data      bairro    ap  codigo_da_rp  \
# 911           MANHA  26/10/2020  PRACA SECA  AP 4           4.1
# 1489          MANHA  29/10/2020       RAMOS  AP 3           3.1
# 1493          TARDE  29/10/2020       RAMOS  AP 3           3.1
# 1531          MANHA  29/10/2020      GALEAO  AP 3           3.7
# 1572  NAO SE APLICA  27/10/2020      OLARIA  AP 3           3.1
#
#                             rp  codigo_da_ra                       ra  \
# 911          4.1 - JACAREPAGUA            16        XVI - JACAREPAGUA
# 1489               3.1 - RAMOS            10                X - RAMOS
# 1493               3.1 - RAMOS            10                X - RAMOS
# 1531  3.7 - ILHA DO GOVERNADOR            20  XX - ILHA DO GOVERNADOR
# 1572               3.1 - RAMOS            10                X - RAMOS
#
#                latitude          longitude situacao_entrevista  \
# 911   -22,8959289159999  -43,3510019129999            POSSIVEL
# 1489  -22,8555496399999  -43,2521390539999            POSSIVEL
# 1493  -22,8555496399999  -43,2521390539999            POSSIVEL
# 1531        -22,8250472        -43,2318929            POSSIVEL
# 1572      -22,839093615      -43,260984916            POSSIVEL
#
#      motivo_situacao_impossivel dormiu_na_rua_ultimos_7_dias  \
# 911                OUTRO MOTIVO                          SIM
# 1489              NAO INFORMADO                          SIM
# 1493              NAO INFORMADO                          SIM
# 1531              NAO INFORMADO                          SIM
# 1572              NAO SE APLICA                NAO SE APLICA
#
#      respondeu_ao_questionario questionario_de_observacao  idade  \
# 911                        SIM                        NAO    999
# 1489                       SIM                        NAO    999
# 1493                       SIM                        NAO    999
# 1531                       SIM                        NAO    999
# 1572             NAO SE APLICA                        NAO    999
#
#           faixa_etaria classificacao_idade faixa_etaria_observada       sexo  \
# 911   NAO IDENTIFICADA      SEM INFORMACAO          NAO SE APLICA   FEMININO
# 1489  NAO IDENTIFICADA      SEM INFORMACAO          NAO SE APLICA   FEMININO
# 1493  NAO IDENTIFICADA      SEM INFORMACAO          NAO SE APLICA  MASCULINO
# 1531  NAO IDENTIFICADA      SEM INFORMACAO          NAO SE APLICA  MASCULINO
# 1572  NAO IDENTIFICADA      SEM INFORMACAO          NAO SE APLICA   FEMININO
#
#           genero cor_raca deficiencia_caminhar_ou_degraus  \
# 911   MULHER CIS    PRETA                  NAO SELECIONOU
# 1489  MULHER CIS    PRETA                  NAO SELECIONOU
# 1493   HOMEM CIS    PRETA                  NAO SELECIONOU
# 1531   HOMEM CIS    PRETA                             SIM
# 1572  MULHER CIS    PARDA                  NAO SELECIONOU
#
#      deficiencia_enxergar deficiencia_ouvir deficiencia_mental  \
# 911        NAO SELECIONOU    NAO SELECIONOU     NAO SELECIONOU
# 1489       NAO SELECIONOU    NAO SELECIONOU     NAO SELECIONOU
# 1493       NAO SELECIONOU    NAO SELECIONOU     NAO SELECIONOU
# 1531                  SIM               SIM     NAO SELECIONOU
# 1572       NAO SELECIONOU    NAO SELECIONOU     NAO SELECIONOU
#
#      deficiencia_nao_possui deficiencia_ns_nr  \
# 911          NAO SELECIONOU    NAO SELECIONOU
# 1489                    SIM    NAO SELECIONOU
# 1493                    SIM    NAO SELECIONOU
# 1531         NAO SELECIONOU    NAO SELECIONOU
# 1572                    SIM    NAO SELECIONOU
#
#      documento_certidao_de_nascimento             documento_cpf  \
# 911                             TENHO  TIVE, MAS NAO TENHO MAIS
# 1489                            TENHO                     TENHO
# 1493                            TENHO                     TENHO
# 1531         TIVE, MAS NAO TENHO MAIS  TIVE, MAS NAO TENHO MAIS
# 1572                            TENHO                     TENHO
#
#      documento_carteira_de_identidade documento_carteira_de_trabalho  \
# 911                        NUNCA TIVE                     NUNCA TIVE
# 1489                            TENHO                          TENHO
# 1493                            TENHO                          TENHO
# 1531         TIVE, MAS NAO TENHO MAIS       TIVE, MAS NAO TENHO MAIS
# 1572         TIVE, MAS NAO TENHO MAIS                     NUNCA TIVE
#
#      documento_titulo_de_eleitor      documento_passaporte  \
# 911                   NUNCA TIVE  TIVE, MAS NAO TENHO MAIS
# 1489                       TENHO                     TENHO
# 1493                       TENHO                     TENHO
# 1531    TIVE, MAS NAO TENHO MAIS                NUNCA TIVE
# 1572    TIVE, MAS NAO TENHO MAIS                NUNCA TIVE
#
#                  documento_red  \
# 911   TIVE, MAS NAO TENHO MAIS
# 1489                     TENHO
# 1493                     TENHO
# 1531                NUNCA TIVE
# 1572                NUNCA TIVE
#
#                                         naturalidade          estado  \
# 911   EM OUTRO MUNICIPIO DO ESTADO DO RIO DE JANEIRO  RIO DE JANEIRO
# 1489                  NO MUNICIPIO DO RIO DE JANEIRO  RIO DE JANEIRO
# 1493                  NO MUNICIPIO DO RIO DE JANEIRO  RIO DE JANEIRO
# 1531                  NO MUNICIPIO DO RIO DE JANEIRO  RIO DE JANEIRO
# 1572  EM OUTRO MUNICIPIO DO ESTADO DO RIO DE JANEIRO  RIO DE JANEIRO
#
#           municipio voltar_cidade_natal contato_familia  \
# 911           MACAE               NS/NR             SIM
# 1489  NAO SE APLICA       NAO SE APLICA             SIM
# 1493  NAO SE APLICA       NAO SE APLICA             NAO
# 1531  NAO SE APLICA       NAO SE APLICA             SIM
# 1572           MAGE                 NAO             SIM
#
#      contato_familia_complemento familia_dorme_rua_acolhimento    ha_criancas  \
# 911                          SIM                 NAO SE APLICA  NAO SE APLICA
# 1489                         SIM                 NAO SE APLICA  NAO SE APLICA
# 1493                         NAO                 NAO SE APLICA  NAO SE APLICA
# 1531                         SIM                 NAO SE APLICA  NAO SE APLICA
# 1572                         SIM                           NAO  NAO SE APLICA
#
#      residencia_fixa residencia_fixa_complemento  \
# 911              SIM                         SIM
# 1489             NAO                         NAO
# 1493             NAO                         NAO
# 1531             NAO                         NAO
# 1572             NAO                         NAO
#
#      dias_dormiu_rua_ultimos_30dias                    motivo_dormir_rua  \
# 911                ENTRE 2 E 5 DIAS                        NAO SE APLICA
# 1489                  TODOS OS DIAS                        NAO SE APLICA
# 1493                  TODOS OS DIAS                        NAO SE APLICA
# 1531                  TODOS OS DIAS                        NAO SE APLICA
# 1572                  TODOS OS DIAS  SOFRIA AMEACAS, ABUSOS OU VIOLENCIA
#
#                    tempo_rua_rj rua_inicio_coronavirus  \
# 911               NAO SE APLICA          NAO SE APLICA
# 1489              NAO SE APLICA          NAO SE APLICA
# 1493              NAO SE APLICA          NAO SE APLICA
# 1531              NAO SE APLICA          NAO SE APLICA
# 1572  MAIS DE 5 ANO ATE 10 ANOS                    NAO
#
#      motivo_rua_depois_coronavirus ajuda_pandemia ajuda_auxilio_emergencial  \
# 911                  NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1489                 NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1493                 NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1531                 NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1572                 NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
#
#      ajuda_alimentos ajuda_itens_higiene ajuda_mascaras_protecao  \
# 911    NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 1489   NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 1493   NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 1531   NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 1572   NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
#
#      ajuda_oferta_lugares_higiene    ajuda_ns_nr local_anterior_dormitorio  \
# 911                 NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1489                NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1493                NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1531                NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1572                NAO SE APLICA  NAO SE APLICA   EM DOMICILIO PARTICULAR
#
#      local_dormitorio dormiu_rua_maioria_ultimos_7dias  \
# 911     NAO SE APLICA                              RUA
# 1489    NAO SE APLICA                              RUA
# 1493    NAO SE APLICA                              RUA
# 1531    NAO SE APLICA                              RUA
# 1572            NS/NR                              RUA
#
#                                   lugar_7_dias  bairro_7_dias  \
# 911                              NAO SE APLICA  NAO SE APLICA
# 1489                             NAO SE APLICA  NAO SE APLICA
# 1493                             NAO SE APLICA  NAO SE APLICA
# 1531                             NAO SE APLICA  NAO SE APLICA
# 1572  EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO          PENHA
#
#      permanece_abrigo_prefeitura dormiu_abrigo_quanto_tempo  \
# 911                    PERMANECE              NAO SE APLICA
# 1489               NAO PERMANECE              NAO SE APLICA
# 1493               NAO PERMANECE              NAO SE APLICA
# 1531               NAO PERMANECE              NAO SE APLICA
# 1572               NAO PERMANECE              NAO SE APLICA
#
#      dificuldade_abrigo abrigos_apresentam_problemas  \
# 911       NAO SE APLICA                NAO SE APLICA
# 1489      NAO SE APLICA                NAO SE APLICA
# 1493      NAO SE APLICA                NAO SE APLICA
# 1531      NAO SE APLICA                NAO SE APLICA
# 1572      NAO SE APLICA                          SIM
#
#                               principal_problema_abrigo foi_atendido_cras  \
# 911                                       NAO SE APLICA               SIM
# 1489                                      NAO SE APLICA    NAO SELECIONOU
# 1493                                      NAO SE APLICA               SIM
# 1531                                      NAO SE APLICA               SIM
# 1572  DIFICULDADE DE RELACIONAMENTO, AMEACAS OU VIOL...    NAO SELECIONOU
#
#      foi_atendido_creas foi_atendido_centro_pop foi_atendido_abordagem_social  \
# 911                 SIM          NAO SELECIONOU                NAO SELECIONOU
# 1489                SIM                     SIM                NAO SELECIONOU
# 1493                SIM                     SIM                NAO SELECIONOU
# 1531     NAO SELECIONOU          NAO SELECIONOU                           SIM
# 1572     NAO SELECIONOU          NAO SELECIONOU                NAO SELECIONOU
#
#      foi_atendido_conselho_tutelar foi_atendido_acolhimento  \
# 911                 NAO SELECIONOU           NAO SELECIONOU
# 1489                NAO SELECIONOU           NAO SELECIONOU
# 1493                NAO SELECIONOU           NAO SELECIONOU
# 1531                NAO SELECIONOU           NAO SELECIONOU
# 1572                NAO SELECIONOU           NAO SELECIONOU
#
#      foi_atendido_central_de_recepcao foi_atendido_hotel  \
# 911                    NAO SELECIONOU     NAO SELECIONOU
# 1489                   NAO SELECIONOU     NAO SELECIONOU
# 1493                   NAO SELECIONOU     NAO SELECIONOU
# 1531                   NAO SELECIONOU     NAO SELECIONOU
# 1572                   NAO SELECIONOU     NAO SELECIONOU
#
#      foi_atendido_defensoria_publica foi_atendido_nao_foi_atendido  \
# 911                   NAO SELECIONOU                NAO SELECIONOU
# 1489                  NAO SELECIONOU                NAO SELECIONOU
# 1493                  NAO SELECIONOU                NAO SELECIONOU
# 1531                  NAO SELECIONOU                NAO SELECIONOU
# 1572                  NAO SELECIONOU                           SIM
#
#      foi_atendido_ns/nr dificuldades_atendimento_servico  \
# 911      NAO SELECIONOU                    NAO SE APLICA
# 1489     NAO SELECIONOU                    NAO SE APLICA
# 1493     NAO SELECIONOU                    NAO SE APLICA
# 1531     NAO SELECIONOU                    NAO SE APLICA
# 1572     NAO SELECIONOU                    NAO SE APLICA
#
#             atividade_remunerada                  atividade_realizada  \
# 911   SIM, SEM CARTEIRA ASSINADA  CATAR MATERIAIS RECICLAVEIS OU LIXO
# 1489  SIM, SEM CARTEIRA ASSINADA  CATAR MATERIAIS RECICLAVEIS OU LIXO
# 1493  SIM, SEM CARTEIRA ASSINADA  CATAR MATERIAIS RECICLAVEIS OU LIXO
# 1531  SIM, SEM CARTEIRA ASSINADA  CATAR MATERIAIS RECICLAVEIS OU LIXO
# 1572  SIM, SEM CARTEIRA ASSINADA                                OUTRA
#
#      recebe_outras_fontes_de_renda outras_fontes_bolsa_familia  \
# 911                            SIM              NAO SELECIONOU
# 1489                           SIM              NAO SELECIONOU
# 1493                           SIM              NAO SELECIONOU
# 1531                           SIM                         SIM
# 1572                           SIM              NAO SELECIONOU
#
#      outras_fontes_aux_emergencial outras_fontes_bpc  \
# 911                            SIM    NAO SELECIONOU
# 1489                           SIM    NAO SELECIONOU
# 1493                NAO SELECIONOU    NAO SELECIONOU
# 1531                           SIM    NAO SELECIONOU
# 1572                NAO SELECIONOU    NAO SELECIONOU
#
#      outras_fontes_aposentado_pensao outras_fontes_auxilio_doenca  \
# 911                   NAO SELECIONOU               NAO SELECIONOU
# 1489                  NAO SELECIONOU               NAO SELECIONOU
# 1493                  NAO SELECIONOU               NAO SELECIONOU
# 1531                  NAO SELECIONOU               NAO SELECIONOU
# 1572                  NAO SELECIONOU               NAO SELECIONOU
#
#      outras_fontes_aht_aluguel_social outras_fontes_outros  \
# 911                    NAO SELECIONOU       NAO SELECIONOU
# 1489                   NAO SELECIONOU       NAO SELECIONOU
# 1493                   NAO SELECIONOU       NAO SELECIONOU
# 1531                   NAO SELECIONOU       NAO SELECIONOU
# 1572                   NAO SELECIONOU       NAO SELECIONOU
#
#      outras_fontes_nao_recebe outras_fontes_ns/nr       gravidez  \
# 911            NAO SELECIONOU      NAO SELECIONOU            SIM
# 1489           NAO SELECIONOU      NAO SELECIONOU            NAO
# 1493                      SIM      NAO SELECIONOU  NAO SE APLICA
# 1531           NAO SELECIONOU      NAO SELECIONOU  NAO SE APLICA
# 1572                      SIM      NAO SELECIONOU            SIM
#
#      acompanhamento_pre_natal problema_saude_diabetes  \
# 911                       SIM                     NAO
# 1489            NAO SE APLICA                     NAO
# 1493            NAO SE APLICA                     NAO
# 1531            NAO SE APLICA                     NAO
# 1572                      SIM                     NAO
#
#      problema_saude_pressao_alta problema_saude_hiv_aids  \
# 911                          NAO                     NAO
# 1489                         NAO                     NAO
# 1493                         SIM                     NAO
# 1531                         NAO                     NAO
# 1572                         NAO                     NAO
#
#      problema_saude_sifilis_ou_ists problema_saude_asma_bronq_pneum  \
# 911                             NAO                             NAO
# 1489                            NAO                             NAO
# 1493                            NAO                             NAO
# 1531                            NAO                             NAO
# 1572                            NAO                             NAO
#
#      problema_saude_tuberculose problema_saude_cancer_tumores  \
# 911                         NAO                           NAO
# 1489                        NAO                           NAO
# 1493                        NAO                           NAO
# 1531                        NAO                           NAO
# 1572                        NAO                           NAO
#
#      problema_saude_hepatite problema_saude_mental_epilepsia  \
# 911                      NAO                             NAO
# 1489                     NAO                             NAO
# 1493                     NAO                             NAO
# 1531                     NAO                             NAO
# 1572                     NAO                             SIM
#
#      problema_saude_lepra_outras problema_saude_infeccao_urinaria  \
# 911                          NAO                              NAO
# 1489                         NAO                              NAO
# 1493                         NAO                              NAO
# 1531                         NAO                              NAO
# 1572                         NAO                              SIM
#
#      problema_saude_ferim_frat_outros         qual_unidade_saude_procura  \
# 911                               NAO                                UPA
# 1489                              NAO  CLINICA DA FAMILIA/POSTO DE SAUDE
# 1493                              NAO                              NS/NR
# 1531                              SIM                    HOSPITAL OU CER
# 1572                              NAO  CLINICA DA FAMILIA/POSTO DE SAUDE
#
#      faz_uso_drogas drogas_tabaco drogas_alcool drogas_maconha_haxixe  \
# 911             SIM           NAO           SIM                   SIM
# 1489            SIM           SIM           SIM                   SIM
# 1493            SIM           NAO           NAO                   NAO
# 1531            SIM           SIM           SIM                   SIM
# 1572            SIM           SIM           NAO                   NAO
#
#      drogas_crack_similares drogas_cocaina drogas_inalan_cola_solven_tiner  \
# 911                     SIM            SIM                             SIM
# 1489                    SIM            SIM                             SIM
# 1493                    NAO            SIM                             NAO
# 1531                    SIM            SIM                             NAO
# 1572                    NAO            SIM                             NAO
#
#      frequencia_tabaco frequencia_alcool frequencia_maconha/haxixe  \
# 911      NAO SE APLICA  ENTRE 3 E 6 DIAS          ENTRE 3 E 6 DIAS
# 1489     TODOS OS DIAS     TODOS OS DIAS             TODOS OS DIAS
# 1493     NAO SE APLICA     NAO SE APLICA             NAO SE APLICA
# 1531     TODOS OS DIAS     TODOS OS DIAS          ENTRE 1 E 2 DIAS
# 1572             NS/NR     NAO SE APLICA             NAO SE APLICA
#
#      frequencia_crack/similares frequencia_cocaina  \
# 911            ENTRE 3 E 6 DIAS   ENTRE 3 E 6 DIAS
# 1489              TODOS OS DIAS      TODOS OS DIAS
# 1493              NAO SE APLICA   ENTRE 1 E 2 DIAS
# 1531           ENTRE 1 E 2 DIAS           NAO USOU
# 1572              NAO SE APLICA              NS/NR
#
#      frequencia_inal_cola_solv_tiner  \
# 911                    NAO SE APLICA
# 1489                   TODOS OS DIAS
# 1493                   NAO SE APLICA
# 1531                   NAO SE APLICA
# 1572                   NAO SE APLICA
#
#                                            motivo_droga  \
# 911   SENTIU VONTADE/CURIOSIDADE DE TER O EFEITO DA ...
# 1489  SENTIU VONTADE/CURIOSIDADE DE TER O EFEITO DA ...
# 1493  PERDAS AFETIVAS OU PROBLEMAS FAMILIARES (PERDA...
# 1531  PERDAS AFETIVAS OU PROBLEMAS FAMILIARES (PERDA...
# 1572                                              NS/NR
#
#                               motivo_local_uso_droga sabe_ler_escrever  \
# 911                                   PRECO DA DROGA               SIM
# 1489  JA ESTAVA NO BAIRRO/LOCALIDADE POR OUTRA RAZAO               SIM
# 1493                    REPRESSAO NO LOCAL ONDE MORA               SIM
# 1531              ONDE OS AMIGOS SE REUNEM PARA USAR               SIM
# 1572                                   NAO SE APLICA               SIM
#
#      frequentou_escola            escolaridade necessidade_sair_situacao  \
# 911    SIM, JA ESTUDEI                INFANTIL                  DINHEIRO
# 1489   SIM, JA ESTUDEI  FUNDAMENTAL INCOMPLETO                   FAMILIA
# 1493   SIM, JA ESTUDEI        MEDIO INCOMPLETO     NAO QUERO SAIR DA RUA
# 1531   SIM, JA ESTUDEI  FUNDAMENTAL INCOMPLETO                   MORADIA
# 1572   SIM, JA ESTUDEI  FUNDAMENTAL INCOMPLETO                   EMPREGO
#
#        zona    ids
# 911   OESTE  0.598
# 1489  NORTE  0.610
# 1493  NORTE  0.610
# 1531  NORTE  0.548
# 1572  NORTE  0.603

# %% [markdown]
# Utilizando a técnica de Z-SCORE para encontrar outliers percebemos que as idades preenchidas com o valor "999" são de indivíduos que se encontravam em cenas de uso de drogas o que realmente tornam os dados imprecisos.
#
# Como o dataset é muito heterogêneo e temos gêneros distintos, cada indivíduo teve a informação preenchida com a media de idade do seu respectivo gênero .

# %%
media_homem = int(np.mean(df_clean.loc[(df_clean['genero'] == 'HOMEM CIS') & (df_clean['idade'] != '999'), 'idade']))
media_mulher = int(np.mean(df_clean.loc[(df_clean['genero'] == 'MULHER CIS') & (df_clean['idade'] != '999'), 'idade']))
df_clean.loc[(np.abs(stats.zscore(df_clean['idade'])) >= 3) & (df_clean['genero'] == 'MULHER CIS'), ['idade']] = media_mulher
df_clean.loc[(np.abs(stats.zscore(df_clean['idade'])) >= 3) & (df_clean['genero'] == 'HOMEM CIS'), ['idade']] = media_homem

# %% [markdown]
# Checando novamente percebemos que ainda existem outliers, mas são valores referentes a idade que são perfeitamente possíveis de existir.

# %%
df_clean.loc[(np.abs(stats.zscore(df_clean['idade'])) >= 3)]
# Out:
# Warning: Total number of columns (131) exceeds max_columns (20). Falling back to pandas display.
#         id rua_acolhimento local_da_coleta_de_dados      metodo  turno  \
# 15     118             RUA                      RUA  ENTREVISTA  MANHA
# 147    153             RUA                      RUA  ENTREVISTA  MANHA
# 901   2240             RUA                      RUA  ENTREVISTA  NOITE
# 1131  1897             RUA                      RUA  ENTREVISTA  NOITE
# 1465  4643             RUA             CENAS DE USO  ENTREVISTA  TARDE
#
#             data             bairro    ap  codigo_da_rp                  rp  \
# 15    26/10/2020       CAMPO GRANDE  AP 5           5.2  5.2 - CAMPO GRANDE
# 147   26/10/2020   MAGALHAES BASTOS  AP 5           5.1         5.1 - BANGU
# 901   29/10/2020  PRACA DA BANDEIRA  AP 2           2.2        2.2 - TIJUCA
# 1131  28/10/2020           BOTAFOGO  AP 2           2.1      2.1 - ZONA SUL
# 1465  29/10/2020              RAMOS  AP 3           3.1         3.1 - RAMOS
#
#       codigo_da_ra                    ra      latitude     longitude  \
# 15              18  XVIII - CAMPO GRANDE   -22,9016338   -43,5564876
# 147             33     XXXIII - REALENGO   -22,8673057   -43,4121803
# 901              8         VIII - TIJUCA   -22,9099218   -43,2158636
# 1131             4         IV - BOTAFOGO  -22,95044549  -43,19279681
# 1465            10             X - RAMOS   -22,8540798   -43,2488369
#
#      situacao_entrevista motivo_situacao_impossivel  \
# 15              POSSIVEL              NAO SE APLICA
# 147             POSSIVEL              NAO SE APLICA
# 901             POSSIVEL              NAO SE APLICA
# 1131            POSSIVEL              NAO SE APLICA
# 1465            POSSIVEL              NAO INFORMADO
#
#      dormiu_na_rua_ultimos_7_dias respondeu_ao_questionario  \
# 15                            SIM                       SIM
# 147                           SIM                       SIM
# 901                           SIM                       SIM
# 1131                          SIM                       SIM
# 1465                          SIM                       SIM
#
#      questionario_de_observacao  idade faixa_etaria classificacao_idade  \
# 15                          NAO     77      70 A 79               IDOSO
# 147                         NAO     79      70 A 79               IDOSO
# 901                         NAO     84      80 A 89               IDOSO
# 1131                        NAO     80      80 A 89               IDOSO
# 1465                        NAO     80      80 A 89               IDOSO
#
#      faixa_etaria_observada       sexo     genero cor_raca  \
# 15            NAO SE APLICA  MASCULINO  HOMEM CIS   BRANCA
# 147           NAO SE APLICA  MASCULINO  HOMEM CIS    PARDA
# 901           NAO SE APLICA  MASCULINO  HOMEM CIS    PRETA
# 1131          NAO SE APLICA  MASCULINO  HOMEM CIS   BRANCA
# 1465          NAO SE APLICA  MASCULINO  HOMEM CIS   BRANCA
#
#      deficiencia_caminhar_ou_degraus deficiencia_enxergar deficiencia_ouvir  \
# 15                    NAO SELECIONOU       NAO SELECIONOU    NAO SELECIONOU
# 147                   NAO SELECIONOU       NAO SELECIONOU    NAO SELECIONOU
# 901                              SIM                  SIM    NAO SELECIONOU
# 1131                             SIM                  SIM               SIM
# 1465                  NAO SELECIONOU       NAO SELECIONOU    NAO SELECIONOU
#
#      deficiencia_mental deficiencia_nao_possui deficiencia_ns_nr  \
# 15       NAO SELECIONOU                    SIM    NAO SELECIONOU
# 147      NAO SELECIONOU                    SIM    NAO SELECIONOU
# 901      NAO SELECIONOU         NAO SELECIONOU    NAO SELECIONOU
# 1131     NAO SELECIONOU         NAO SELECIONOU    NAO SELECIONOU
# 1465     NAO SELECIONOU                    SIM    NAO SELECIONOU
#
#      documento_certidao_de_nascimento             documento_cpf  \
# 15                              TENHO                     TENHO
# 147          TIVE, MAS NAO TENHO MAIS  TIVE, MAS NAO TENHO MAIS
# 901          TIVE, MAS NAO TENHO MAIS  TIVE, MAS NAO TENHO MAIS
# 1131                            TENHO                     TENHO
# 1465                            TENHO                     TENHO
#
#      documento_carteira_de_identidade documento_carteira_de_trabalho  \
# 15                              TENHO                          TENHO
# 147          TIVE, MAS NAO TENHO MAIS       TIVE, MAS NAO TENHO MAIS
# 901          TIVE, MAS NAO TENHO MAIS       TIVE, MAS NAO TENHO MAIS
# 1131                            TENHO                          TENHO
# 1465                            TENHO                          TENHO
#
#      documento_titulo_de_eleitor      documento_passaporte  \
# 15                         TENHO                NUNCA TIVE
# 147     TIVE, MAS NAO TENHO MAIS                NUNCA TIVE
# 901     TIVE, MAS NAO TENHO MAIS  TIVE, MAS NAO TENHO MAIS
# 1131                       TENHO                NUNCA TIVE
# 1465                       TENHO                NUNCA TIVE
#
#                  documento_red  \
# 15                  NUNCA TIVE
# 147                 NUNCA TIVE
# 901   TIVE, MAS NAO TENHO MAIS
# 1131                     TENHO
# 1465                NUNCA TIVE
#
#                                         naturalidade          estado  \
# 15                    NO MUNICIPIO DO RIO DE JANEIRO  RIO DE JANEIRO
# 147                   NO MUNICIPIO DO RIO DE JANEIRO  RIO DE JANEIRO
# 901                                  EM OUTRO ESTADO         PARAIBA
# 1131  EM OUTRO MUNICIPIO DO ESTADO DO RIO DE JANEIRO  RIO DE JANEIRO
# 1465                  NO MUNICIPIO DO RIO DE JANEIRO  RIO DE JANEIRO
#
#           municipio voltar_cidade_natal contato_familia  \
# 15    NAO SE APLICA       NAO SE APLICA             SIM
# 147   NAO SE APLICA       NAO SE APLICA             NAO
# 901   NAO SE APLICA                 NAO             NAO
# 1131         MARICA                 SIM             NAO
# 1465  NAO SE APLICA       NAO SE APLICA             SIM
#
#      contato_familia_complemento familia_dorme_rua_acolhimento    ha_criancas  \
# 15                           SIM                           NAO            NAO
# 147                          NAO                           NAO            NAO
# 901                          NAO                           NAO            NAO
# 1131                         NAO                           NAO            NAO
# 1465                         SIM                 NAO SE APLICA  NAO SE APLICA
#
#      residencia_fixa residencia_fixa_complemento  \
# 15               NAO                         NAO
# 147              NAO                         NAO
# 901              NAO                         NAO
# 1131             NAO                         NAO
# 1465             SIM                         SIM
#
#      dias_dormiu_rua_ultimos_30dias                        motivo_dormir_rua  \
# 15                    TODOS OS DIAS  CONFLITOS FAMILIARES (INCLUI SEPARACAO)
# 147                   TODOS OS DIAS  CONFLITOS FAMILIARES (INCLUI SEPARACAO)
# 901                   TODOS OS DIAS            ANDARILHO / NOMADE / VIAJANTE
# 1131                  TODOS OS DIAS                                   OUTROS
# 1465                          1 DIA                            NAO SE APLICA
#
#                    tempo_rua_rj rua_inicio_coronavirus  \
# 15    MAIS DE 1 MES ATE 6 MESES                    NAO
# 147    MAIS DE 1 ANO ATE 5 ANOS                    NAO
# 901    MAIS DE 1 ANO ATE 5 ANOS                    NAO
# 1131   MAIS DE 1 ANO ATE 5 ANOS                    NAO
# 1465              NAO SE APLICA          NAO SE APLICA
#
#      motivo_rua_depois_coronavirus ajuda_pandemia ajuda_auxilio_emergencial  \
# 15                   NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 147                  NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 901                  NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1131                 NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
# 1465                 NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
#
#      ajuda_alimentos ajuda_itens_higiene ajuda_mascaras_protecao  \
# 15     NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 147    NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 901    NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 1131   NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
# 1465   NAO SE APLICA       NAO SE APLICA           NAO SE APLICA
#
#      ajuda_oferta_lugares_higiene    ajuda_ns_nr local_anterior_dormitorio  \
# 15                  NAO SE APLICA  NAO SE APLICA   EM DOMICILIO PARTICULAR
# 147                 NAO SE APLICA  NAO SE APLICA   EM DOMICILIO PARTICULAR
# 901                 NAO SE APLICA  NAO SE APLICA                     NS/NR
# 1131                NAO SE APLICA  NAO SE APLICA   EM DOMICILIO PARTICULAR
# 1465                NAO SE APLICA  NAO SE APLICA             NAO SE APLICA
#
#                               local_dormitorio  \
# 15    EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO
# 147   EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO
# 901                              NAO SE APLICA
# 1131  EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO
# 1465                             NAO SE APLICA
#
#      dormiu_rua_maioria_ultimos_7dias  \
# 15                                RUA
# 147                               RUA
# 901                               RUA
# 1131                              RUA
# 1465                              RUA
#
#                                   lugar_7_dias     bairro_7_dias  \
# 15    EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO      CAMPO GRANDE
# 147   EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO  MAGALHAES BASTOS
# 901   EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO     SAO CRISTOVAO
# 1131  EM UM BAIRRO DA CIDADE DO RIO DE JANEIRO          BOTAFOGO
# 1465                             NAO SE APLICA     NAO SE APLICA
#
#      permanece_abrigo_prefeitura dormiu_abrigo_quanto_tempo  \
# 15                 NAO PERMANECE                      NS/NR
# 147                NAO PERMANECE  MAIS DE 1 MES ATE 3 MESES
# 901                NAO PERMANECE        MENOS DE UMA SEMANA
# 1131               NAO PERMANECE             MAIS DE 3 ANOS
# 1465               NAO PERMANECE              NAO SE APLICA
#
#      dificuldade_abrigo abrigos_apresentam_problemas  \
# 15                  SIM                          SIM
# 147                 NAO                          SIM
# 901                 NAO                          NAO
# 1131                SIM                          SIM
# 1465      NAO SE APLICA                NAO SE APLICA
#
#                               principal_problema_abrigo foi_atendido_cras  \
# 15                                               OUTROS               SIM
# 147   DIFICULDADE DE RELACIONAMENTO, AMEACAS OU VIOL...               SIM
# 901                                       NAO SE APLICA    NAO SELECIONOU
# 1131                                             OUTROS    NAO SELECIONOU
# 1465                                      NAO SE APLICA    NAO SELECIONOU
#
#      foi_atendido_creas foi_atendido_centro_pop foi_atendido_abordagem_social  \
# 15       NAO SELECIONOU          NAO SELECIONOU                NAO SELECIONOU
# 147                 SIM          NAO SELECIONOU                NAO SELECIONOU
# 901      NAO SELECIONOU          NAO SELECIONOU                NAO SELECIONOU
# 1131     NAO SELECIONOU          NAO SELECIONOU                NAO SELECIONOU
# 1465     NAO SELECIONOU          NAO SELECIONOU                           SIM
#
#      foi_atendido_conselho_tutelar foi_atendido_acolhimento  \
# 15                  NAO SELECIONOU           NAO SELECIONOU
# 147                 NAO SELECIONOU           NAO SELECIONOU
# 901                 NAO SELECIONOU           NAO SELECIONOU
# 1131                NAO SELECIONOU           NAO SELECIONOU
# 1465                NAO SELECIONOU           NAO SELECIONOU
#
#      foi_atendido_central_de_recepcao foi_atendido_hotel  \
# 15                     NAO SELECIONOU     NAO SELECIONOU
# 147                    NAO SELECIONOU     NAO SELECIONOU
# 901                    NAO SELECIONOU     NAO SELECIONOU
# 1131                   NAO SELECIONOU     NAO SELECIONOU
# 1465                   NAO SELECIONOU     NAO SELECIONOU
#
#      foi_atendido_defensoria_publica foi_atendido_nao_foi_atendido  \
# 15                    NAO SELECIONOU                NAO SELECIONOU
# 147                   NAO SELECIONOU                NAO SELECIONOU
# 901                   NAO SELECIONOU                NAO SELECIONOU
# 1131                  NAO SELECIONOU                NAO SELECIONOU
# 1465                  NAO SELECIONOU                NAO SELECIONOU
#
#      foi_atendido_ns/nr dificuldades_atendimento_servico  \
# 15       NAO SELECIONOU                              SIM
# 147      NAO SELECIONOU                              NAO
# 901                 SIM                    NAO RESPONDEU
# 1131                SIM                              SIM
# 1465     NAO SELECIONOU                    NAO SE APLICA
#
#             atividade_remunerada                  atividade_realizada  \
# 15    SIM, SEM CARTEIRA ASSINADA  CATAR MATERIAIS RECICLAVEIS OU LIXO
# 147   SIM, SEM CARTEIRA ASSINADA  CATAR MATERIAIS RECICLAVEIS OU LIXO
# 901                        NS/NR                        NAO SE APLICA
# 1131                       NS/NR                        NAO SE APLICA
# 1465                         NAO                        NAO SE APLICA
#
#      recebe_outras_fontes_de_renda outras_fontes_bolsa_familia  \
# 15                             SIM              NAO SELECIONOU
# 147                            SIM              NAO SELECIONOU
# 901                            SIM              NAO SELECIONOU
# 1131                           SIM              NAO SELECIONOU
# 1465                           SIM              NAO SELECIONOU
#
#      outras_fontes_aux_emergencial outras_fontes_bpc  \
# 15                             SIM    NAO SELECIONOU
# 147                 NAO SELECIONOU    NAO SELECIONOU
# 901                 NAO SELECIONOU    NAO SELECIONOU
# 1131                NAO SELECIONOU    NAO SELECIONOU
# 1465                           SIM    NAO SELECIONOU
#
#      outras_fontes_aposentado_pensao outras_fontes_auxilio_doenca  \
# 15                    NAO SELECIONOU               NAO SELECIONOU
# 147                   NAO SELECIONOU               NAO SELECIONOU
# 901                   NAO SELECIONOU               NAO SELECIONOU
# 1131                             SIM               NAO SELECIONOU
# 1465                  NAO SELECIONOU               NAO SELECIONOU
#
#      outras_fontes_aht_aluguel_social outras_fontes_outros  \
# 15                     NAO SELECIONOU       NAO SELECIONOU
# 147                    NAO SELECIONOU       NAO SELECIONOU
# 901                    NAO SELECIONOU       NAO SELECIONOU
# 1131                   NAO SELECIONOU       NAO SELECIONOU
# 1465                   NAO SELECIONOU       NAO SELECIONOU
#
#      outras_fontes_nao_recebe outras_fontes_ns/nr       gravidez  \
# 15             NAO SELECIONOU      NAO SELECIONOU  NAO SE APLICA
# 147                       SIM      NAO SELECIONOU  NAO SE APLICA
# 901            NAO SELECIONOU                 SIM  NAO SE APLICA
# 1131           NAO SELECIONOU      NAO SELECIONOU  NAO SE APLICA
# 1465           NAO SELECIONOU      NAO SELECIONOU  NAO SE APLICA
#
#      acompanhamento_pre_natal problema_saude_diabetes  \
# 15              NAO SE APLICA                     NAO
# 147             NAO SE APLICA                     NAO
# 901             NAO SE APLICA                     NAO
# 1131            NAO SE APLICA                     NAO
# 1465            NAO SE APLICA                     NAO
#
#      problema_saude_pressao_alta problema_saude_hiv_aids  \
# 15                           NAO                     NAO
# 147                          NAO                     NAO
# 901                          NAO                   NS/NR
# 1131                         SIM                     NAO
# 1465                         NAO                     NAO
#
#      problema_saude_sifilis_ou_ists problema_saude_asma_bronq_pneum  \
# 15                              NAO                             NAO
# 147                             NAO                             NAO
# 901                           NS/NR                           NS/NR
# 1131                            NAO                             SIM
# 1465                            NAO                             NAO
#
#      problema_saude_tuberculose problema_saude_cancer_tumores  \
# 15                          NAO                           NAO
# 147                         NAO                           NAO
# 901                       NS/NR                         NS/NR
# 1131                        SIM                           NAO
# 1465                        NAO                           NAO
#
#      problema_saude_hepatite problema_saude_mental_epilepsia  \
# 15                       NAO                             NAO
# 147                      NAO                             NAO
# 901                    NS/NR                             SIM
# 1131                     NAO                             NAO
# 1465                     NAO                             NAO
#
#      problema_saude_lepra_outras problema_saude_infeccao_urinaria  \
# 15                           NAO                              NAO
# 147                          NAO                              NAO
# 901                        NS/NR                            NS/NR
# 1131                         SIM                              SIM
# 1465                         NAO                              NAO
#
#      problema_saude_ferim_frat_outros         qual_unidade_saude_procura  \
# 15                                NAO                    HOSPITAL OU CER
# 147                               NAO                    HOSPITAL OU CER
# 901                             NS/NR                                UPA
# 1131                              SIM  CLINICA DA FAMILIA/POSTO DE SAUDE
# 1465                              NAO                    HOSPITAL OU CER
#
#      faz_uso_drogas drogas_tabaco drogas_alcool drogas_maconha_haxixe  \
# 15              NAO           NAO           NAO                   NAO
# 147             SIM           NAO           NAO                   SIM
# 901             SIM           SIM           SIM                   NAO
# 1131            NAO           NAO           NAO                   NAO
# 1465            NAO           NAO           NAO                   NAO
#
#      drogas_crack_similares drogas_cocaina drogas_inalan_cola_solven_tiner  \
# 15                      NAO            NAO                             NAO
# 147                     NAO            NAO                             NAO
# 901                     NAO            NAO                             NAO
# 1131                    NAO            NAO                             NAO
# 1465                    NAO            NAO                             NAO
#
#      frequencia_tabaco frequencia_alcool frequencia_maconha/haxixe  \
# 15       NAO SE APLICA     NAO SE APLICA             NAO SE APLICA
# 147      NAO SE APLICA     NAO SE APLICA             NAO SE APLICA
# 901      NAO SE APLICA     NAO SE APLICA             NAO SE APLICA
# 1131     NAO SE APLICA     NAO SE APLICA             NAO SE APLICA
# 1465     NAO SE APLICA     NAO SE APLICA             NAO SE APLICA
#
#      frequencia_crack/similares frequencia_cocaina  \
# 15                NAO SE APLICA      NAO SE APLICA
# 147               NAO SE APLICA      NAO SE APLICA
# 901               NAO SE APLICA      NAO SE APLICA
# 1131              NAO SE APLICA      NAO SE APLICA
# 1465              NAO SE APLICA      NAO SE APLICA
#
#      frequencia_inal_cola_solv_tiner              motivo_droga  \
# 15                     NAO SE APLICA             NAO SE APLICA
# 147                    NAO SE APLICA             NAO SE APLICA
# 901                    NAO SE APLICA             NAO SE APLICA
# 1131                   NAO SE APLICA             NAO SE APLICA
# 1465                   NAO SE APLICA  NAO FACO O USO DE DROGAS
#
#      motivo_local_uso_droga sabe_ler_escrever frequentou_escola  \
# 15            NAO SE APLICA               SIM   SIM, JA ESTUDEI
# 147           NAO SE APLICA               SIM   SIM, JA ESTUDEI
# 901           NAO SE APLICA             NS/NR             NS/NR
# 1131          NAO SE APLICA               SIM   SIM, JA ESTUDEI
# 1465          NAO SE APLICA               SIM   SIM, JA ESTUDEI
#
#                 escolaridade necessidade_sair_situacao   zona    ids
# 15    FUNDAMENTAL INCOMPLETO                   MORADIA  OESTE  0.518
# 147   FUNDAMENTAL INCOMPLETO                   EMPREGO  OESTE  0.544
# 901            NAO SE APLICA                DOCUMENTOS  NORTE  0.679
# 1131                   NS/NR                   MORADIA    SUL  0.743
# 1465  FUNDAMENTAL INCOMPLETO                     OUTRO  NORTE  0.610

# %%
sns.boxplot(x=df_clean['idade'])

# %% [markdown]
# ###2.3.3 - Alteração dos tipos de dados

# %%
df_clean = df_clean.apply(lambda x: x.astype('category') if x.dtypes == 'object' or 'codigo' in x.name else x)
df_clean[['latitude', 'longitude']] = df_clean[['latitude', 'longitude']].apply(lambda x: x.str.replace(',', '.').astype('float64'))

# %% [markdown]
# # 3 - Análise exploratória

# %% [markdown]
# Perguntas que eu quero tentar responder durante a análise:
# *   A relação entre indivíduos que deixaram os abrigos é equilibrada em relação aos que permanecem?
# *   Por gênero, quantos indivíduos estão em situação de rua?
# *   Em quais faixas etárias se concentram do indivíduos da amostra?
# *   Problemas apresentados pelos abrigos em cada região.
# *   Motivos para permanecer em situação de rua em relação ao gênero.
# *   Habitos de consumo de drogas por região
# *   Onde se concentram os indivíduos do estudo?

# %%
def gera_heatmap(alvo, por, xlabel, ylabel, title):
  df = df_clean.loc[~df_clean[alvo].isin(['NAO SE APLICA', 'NS/NR']),[alvo, por]]# "~" para negar
  pv = pd.pivot_table(df, index=alvo, columns=por, aggfunc=len, fill_value=0)
  ax = sns.heatmap(pv, cmap="BuPu", annot=True, fmt ='d', linewidths=.5, xticklabels=True, yticklabels=True)
  ax.set_xlabel(xlabel)
  ax.set_ylabel(ylabel)
  ax.set_title(f'{title}\n')
  return ax

# %%
def gera_countplot(alvo, xlabel, ylabel, title):
  ax = sns.countplot(x=df_clean[alvo])
  ax.set_title(f'{title}\n'); 
  ax.set_xlabel(xlabel); 
  ax.set_ylabel(ylabel); 
  return ax

# %% [markdown]
# ##3.1 - Relação entre indivíduos que permanecem nos abrigos ou não.

# %%
cp_permanencia = gera_countplot('permanece_abrigo_prefeitura', 'Resposta', 'Quantidade', 'Permaneceu em abrigos da prefeitura?')
plt.show()

# %% [markdown]
# ## 3.2 - Por gênero, quantos indivíduos estão em situação de rua?

# %%
rua_genero = gera_countplot('genero', 'Gênero', 'Quantidade', 'Gênero dos inivíduos')
plt.show()

# %% [markdown]
# ## 3.3 - Em quais faixas etárias se concentram do indivíduos da amostra?

# %%
cp_faixa = gera_countplot('faixa_etaria', 'Faixa Etária', 'Quantidade', 'Faixa etária dos indivíduos')
plt.show()

# %% [markdown]
# ##3.4 - Problemas apresentados pelos abrigos em cada região.

# %%
hm_problemas_abrigo = gera_heatmap('principal_problema_abrigo', 'zona', 'Zona', 'Problema apresentado', 'Problemas apresentados pelos abrigos - Por Zona')
plt.show()

# %% [markdown]
# ## 3.5 - Motivos para permanecer em situação de rua em relação ao gênero.

# %%
hm_motivos_rua = gera_heatmap('motivo_dormir_rua', 'genero', 'Gênero', 'Motivo para permanência na rua', 'Motivos para pemanência na rua em relação ao gênero')
plt.show()

# %% [markdown]
# ## 3.6 - Habitos de consumo de drogas por região

# %%
drogas = ['drogas_tabaco',
 'drogas_alcool',
 'drogas_maconha_haxixe',
 'drogas_crack_similares',
 'drogas_cocaina',
 'drogas_inalan_cola_solven_tiner']
df_drogas_x_zona = pd.DataFrame()
for d in drogas:  
  df_drogas_x_zona[d] = df_clean.loc[df_clean[d] == 'SIM'].groupby('zona').size().reset_index(name='counts')['counts']
df_drogas_x_zona.index = ['CENTRAL', 'NORTE', 'OESTE', 'SUL']

# %%
sns.heatmap(df_drogas_x_zona, annot=True, cmap="Blues", fmt="d", xticklabels=["Tabaco", "Álcool", "Maconha/Haxixe", "Crack (ou similares)", "Cocaína", "Cola/Solvente/Tiner"]).set_title('Hábitos de consumo de drogas por zona\n')
# Out:
# Text(0.5, 1.0, 'Hábitos de consumo de drogas por zona\n')

# %% [markdown]
# ## 3.7 - Onde se concentram os indivíduos do estudo?

# %%
#Não é uma boa prática expor API KEYS, mas esta é apenas para demonstração.
gmaps.configure(api_key='AIzaSyA_NkRKTHez5cZc0eoj6edpI1XRUDj7JuM')

# %%
localizacoes = df_clean[['latitude', 'longitude']]
heatmap_layer = gmaps.heatmap_layer(localizacoes)
heatmap_layer.max_intensity = 100
heatmap_layer.point_radius = 10
fig = gmaps.figure()
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Analisando o mapa de calor acima percebemos que grande parte dos indivíduos se concentram na zona central do município do Rio de Janeiro. Inicialmente este fato chama a atenção porque a zona central apresenta o segundo maior IDS (Índice de desenvolvimento Social), contudo, conforme apresentado na disciplina Modelagem e Preparação de Dados para Machine Learning não devemos nos prender apenas a fatos, mas também julgamentos.
#
# Ocorre que a zona central do Rio de Janeiro é basicamente comercial, não é primordialmente uma zona residencial, com isso durante a noite/madrugada torna-se um ambiente propício para a habitação de moradores de rua e consumo de drogas.

# %%
df_clean.groupby(['zona']).mean().sort_values('ids', ascending=False)['ids']
# Out:
# zona
# SUL        0.743623
# CENTRAL    0.617401
# NORTE      0.612899
# OESTE      0.562092
# Name: ids, dtype: float64

# %% [markdown]
# # 4 - Modelagem de ML

# %% [markdown]
# Para a criação dos modelos de Machine Learning irei testar 3 algoritmos de classificação: Naive Bayes, Random Forest Classifier, Regressão Logistica.
#
# Separei o processo de modelagem nas seguintes etapas:
#
# 1. Limpeza de dados redundantes
# 2. Separação de bases e conversão de tipos
# 3. Balanceamento dos dados
# 4. Tuning de hiperparâmetros e validação Cruzada

# %% [markdown]
# ##4.1 - Limpeza de dados redundantes

# %% [markdown]
# As features descritas abaixo são redundantes ou apresentam sempre o mesmo valor, ou trazem caracteristicas sobre a pesquisa e não sobre o indivíduo por isso optei por removê-las, no documento que acompanha este notebook detalho os motivos.

# %%
df_clean_ml = df_clean.drop(columns=['id','rua_acolhimento', 'metodo', 'turno', 'data','rp', 'ra', 'situacao_entrevista', 'motivo_situacao_impossivel','respondeu_ao_questionario', 'questionario_de_observacao','faixa_etaria_observada','faz_uso_drogas', 'faixa_etaria'])

# %% [markdown]
# ##4.2 - Conversão de tipos e separação entre bases

# %%
X = df_clean_ml.drop(columns=['permanece_abrigo_prefeitura'])
y = df_clean_ml['permanece_abrigo_prefeitura']

# %%
X = X.apply(lambda x: x.cat.codes if x.dtypes == 'category' else x)

# %%
X_train, X_valid, y_train, y_valid =  train_test_split(X.values, y.values)

# %% [markdown]
# ##4.3 - Balanceamento dos dados e escalonamento dos dados
#
# Como observado no item 3.1 deste trabalho a relação entre indivíduos que permanecem e deixam os abrigos é desbalanceada por isso irei utilizar a técnica de OverSampling para balancear os dados. Além disto, para o algoritmo Logistic Regression os dados precisam ser escalonados para correta interpretação da relevancia dos atributos, por isso executamos também este processo.

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
smote = SMOTE(sampling_strategy='minority')

# %%
X_over, y_over = smote.fit_resample(X, y)

# %%
X_over_train, X_over_valid, y_over_train, y_over_valid =  train_test_split(X_over.values, y_over.values)

# %%
scaler = MinMaxScaler()

# %%
X_over_train_scaled, X_over_valid_scaled = scaler.fit_transform(X_over_train), scaler.fit_transform(X_over_valid)

# %%
X_train_scaled, X_valid_scaled = scaler.fit_transform(X_train), scaler.fit_transform(X_valid)

# %% [markdown]
# ##4.4 - Otimização de hiperparametros e cross-validation

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from yellowbrick.classifier import ConfusionMatrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
def get_dataset_by_model(model, is_train = True, sampled = True):  
  if 'sklearn.linear_model' in str(type(model)) and is_train:
    return X_over_train_scaled
  elif 'sklearn.linear_model' in str(type(model)) and is_train is False:
    return X_over_valid_scaled
  elif ~('sklearn.linear_model' in str(type(model))) and is_train:
    return X_over_train
  elif ~('sklearn.linear_model' in str(type(model))) and is_train is False:
    return X_over_valid

# %%
classificadores = [
    {
        "alg": RandomForestClassifier(),
        "params": {
            "bootstrap": [True],
            "max_depth": [6, 8, 10, 12, 14],
            "criterion": ["gini", "entropy"],
            "n_estimators": range(100, 1100, 100),
            "min_samples_split": [2, 3, 4, 5],
            "min_samples_leaf": [2, 3, 4],
            "max_features": ["auto", "sqrt", "log2"],           
        },
    },
    {
        "alg": LogisticRegression(),
        "params": {
            "max_iter": [2000],
            "penalty": ["l2", 'none'],
            "C": [1.0, 2.0, 3.0]           
        },
    },
]

# %%
modelos = []

for c in classificadores:
  rs = RandomizedSearchCV(c['alg'], 
                          c['params'],
                          n_iter=32,
                          cv=5,
                          verbose=True,
                          return_train_score=True,
                          scoring='accuracy',
                          n_jobs = -1
                          )

  rs.fit(get_dataset_by_model(c['alg']),y_over_train)
  modelos.append(dict({
      'alg':gs.best_estimator_,
      'score':gs.best_score_
   } ))
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:296: UserWarning: The total space of parameters 6 is smaller than n_iter=32. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   UserWarning,
# Fitting 5 folds for each of 6 candidates, totalling 30 fits

# %% [markdown]
# Pela natureza do algoritmo Naive Bayes não há hiperparâmetros relevantes para serem testados, por isso irei executar apenas a validação cruzada.

# %%
nb = GaussianNB()

# %%
kfold = KFold(n_splits=10, shuffle=True)
score = cross_val_score(nb,X_over_train, y_over_train, cv=kfold).mean()
score
# Out:
# 0.6806092250454487

# %%
modelos.append(dict({'alg': nb, 'score': score}))

# %%
rank = pd.DataFrame(modelos)
display(rank)
# Out:
#                                                  alg     score
# 0  (DecisionTreeClassifier(max_depth=14, max_feat...  0.952664
# 1           LogisticRegression(C=3.0, max_iter=2000)  0.903034
# 2                                       GaussianNB()  0.680609

# %%
modelos = [m['alg'] for m in modelos]

# %%
modelos
# Out:
# [RandomForestClassifier(max_depth=14, max_features='sqrt', min_samples_leaf=3,
#                         min_samples_split=5, n_estimators=800),
#  LogisticRegression(C=3.0, max_iter=2000),
#  GaussianNB()]

# %% [markdown]
# ##4.5 - Apresentação de resultados

# %%
def get_results(modelos):
  for m in modelos:
    m.fit(get_dataset_by_model(m), y_over_train)
    prev = m.predict(get_dataset_by_model(m, False))
    print(f"\n\n\n{bcolors.OKGREEN}{m}{bcolors.ENDC} \n {classification_report(y_over_valid, prev)}")
    cm = ConfusionMatrix(m)
    cm.fit(get_dataset_by_model(m), y_over_train)
    cm.score(get_dataset_by_model(m, False), y_over_valid)
    plt.show()

# %%
get_results(modelos)
# Out:
# RandomForestClassifier(max_depth=14, max_features='sqrt', min_samples_leaf=3,
#                        min_samples_split=5, n_estimators=800)
#                 precision    recall  f1-score   support
#
# NAO PERMANECE       0.93      0.97      0.95       378
#     PERMANECE       0.97      0.92      0.94       348
#
#      accuracy                           0.95       726
#     macro avg       0.95      0.95      0.95       726
#  weighted avg       0.95      0.95      0.95       726
# LogisticRegression(C=3.0, max_iter=2000)
#                 precision    recall  f1-score   support
#
# NAO PERMANECE       0.90      0.90      0.90       378
#     PERMANECE       0.89      0.89      0.89       348
#
#      accuracy                           0.89       726
#     macro avg       0.89      0.89      0.89       726
#  weighted avg       0.89      0.89      0.89       726
# GaussianNB()
#                 precision    recall  f1-score   support
#
# NAO PERMANECE       0.90      0.45      0.60       378
#     PERMANECE       0.61      0.94      0.74       348
#
#      accuracy                           0.69       726
#     macro avg       0.75      0.70      0.67       726
#  weighted avg       0.76      0.69      0.67       726

# %% [markdown]
# ##4.6 - Apresentando resultados sem otimizações

# %%
def get_dataset_by_model_so(model, is_train = True):  
  if 'sklearn.linear_model' in str(type(model)) and is_train:
    return X_train_scaled
  elif 'sklearn.linear_model' in str(type(model)) and is_train is False:
    return X_valid_scaled
  elif ~('sklearn.linear_model' in str(type(model))) and is_train:
    return X_train
  elif ~('sklearn.linear_model' in str(type(model))) and is_train is False:
    return X_valid

# %%
def get_results_so(modelos):
  for m in modelos:
    m.fit(get_dataset_by_model_so(m), y_train)
    prev = m.predict(get_dataset_by_model_so(m, False))
    print(f"\n\n\n{bcolors.OKGREEN}{m}{bcolors.ENDC} \n {classification_report(y_valid, prev)}")
    cm = ConfusionMatrix(m)
    cm.fit(get_dataset_by_model_so(m), y_train)
    cm.score(get_dataset_by_model_so(m, False), y_valid)
    plt.show()

# %%
modelos_so = [RandomForestClassifier(), LogisticRegression(max_iter=2000), GaussianNB()]

# %%
get_results_so(modelos_so)
# Out:
# RandomForestClassifier()
#                 precision    recall  f1-score   support
#
# NAO PERMANECE       0.92      1.00      0.96       365
#     PERMANECE       0.75      0.08      0.15        36
#
#      accuracy                           0.92       401
#     macro avg       0.83      0.54      0.55       401
#  weighted avg       0.90      0.92      0.88       401
# LogisticRegression(max_iter=2000)
#                 precision    recall  f1-score   support
#
# NAO PERMANECE       0.92      1.00      0.96       365
#     PERMANECE       0.75      0.08      0.15        36
#
#      accuracy                           0.92       401
#     macro avg       0.83      0.54      0.55       401
#  weighted avg       0.90      0.92      0.88       401
# GaussianNB()
#                 precision    recall  f1-score   support
#
# NAO PERMANECE       0.90      0.16      0.27       365
#     PERMANECE       0.09      0.83      0.16        36
#
#      accuracy                           0.22       401
#     macro avg       0.50      0.49      0.21       401
#  weighted avg       0.83      0.22      0.26       401
